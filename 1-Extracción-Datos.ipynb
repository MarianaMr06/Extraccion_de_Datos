# %% [markdown]
# INSTALACION DE PAQUETERIAS

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ACTIVIDAD 1.1

# %% [markdown]
# IMPORTACION ARCHIVO

# %%
#Carga desde un archivo .xlsx sin indice
df= pd.read_excel('Detalle precios y productos fabricados 2022.xlsx')
#df

# %% [markdown]
# VISUALIZAR INFORMACION

# %%
#Verificamos información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1426 entries, 0 to 1425
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CVE_DOC                    1426 non-null   object
#  1   FECHA_DOC                  1426 non-null   datetime64[ns]
#  2   NOMBRE_VENDEDOR            1424 non-null   object
#  3   NOMBRE_CLIENTE             1426 non-null   object
#  4   CANT                       1426 non-null   int64
#  5   CVE_ART                    1426 non-null   object
#  6   DESCR                      1426 non-null   object
#  7   PRECIO_UNITARIO            1426 non-null   float64
#  8   COSTO_UNITARIO             1426 non-null   float64
#  9   COSTO_UNITARIO_CALCULADO   1426 non-null   float64
#  10  SUBTOTAL_PARTIDA           1426 non-null   float64
#  11  COSTO_TOTAL_CALCULADO      1426 non-null   float64
#  12  MARGEN_UNITARIO_CALCULADO  1426 non-null   float64
# ...

# %%
df.head()
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  \
# 0  F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# 1  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE
# 2  F37041 2022-01-05   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN          OMAR RODRIGUEZ GOMEZ
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
#
#    CANT   CVE_ART                                    DESCR  PRECIO_UNITARIO  \
# 0     1  TUE00244  TUB COBRE 5/16"ØX165MM CIRCULA1.5KW127V           434.48
# 1     1  TUA00028  TUA U" 5/16 ØX250MM 1200W 120V TAP1"NPT          1264.05
# 2     7    TP0007     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 7 MT           551.61
# 3     1    TP0001     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 1 MT           140.00
# 4     2   BP00242  BAN P INOX 115MMX235MM 1000W 127V T/TOR           172.41
#
# ...

# %% [markdown]
# FILTROS BASICOS PARA VARIABLES CUALITATIVAS

# %%
#Filtro por objeto
filtro1=df[df["NOMBRE_CLIENTE"] == "PÚBLICO EN GENERAL"]
filtro1
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR      NOMBRE_CLIENTE  CANT  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL     1
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL     2
# 5     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL     2
# 57    F37134 2022-01-17  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL     4
# 69    F37153 2022-01-20  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL     2
# ...      ...        ...                        ...                 ...   ...
# 1371  F39748 2022-12-09  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL     2
# 1375  F39752 2022-12-13         AARON NUÑO CORDOVA  PÚBLICO EN GENERAL     1
# 1376  F39754 2022-12-13  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL     4
# 1392  F39780 2022-12-16  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL     1
# 1410  F39817 2022-12-22  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL     2
#
# ...

# %%
#Filtro por filas
#filtro2= df.iloc[3:10,: ]           #Filas consecutivas
filtro2=df.iloc[ [8, 24, 100, 987, 1000] , : ]   #Filas no consecutivas
filtro2
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 8     F37048 2022-01-05   DIEGO ARMANDO LEON DURAN
# 24    F37069 2022-01-07         AARON NUÑO CORDOVA
# 100   F37223 2022-01-28  LETICIA RAMIREZ HERNANDEZ
# 987   F38970 2022-09-02  LETICIA RAMIREZ HERNANDEZ
# 1000  F39005 2022-09-07  LETICIA RAMIREZ HERNANDEZ
#
#                                         NOMBRE_CLIENTE  CANT   CVE_ART  \
# 8                                   FIDEICOMISO F/1596     1  TUE00207
# 24                                   ADVANEX DE MEXICO     2   RP00150
# 100   COMPONENTES ELECTRICOS Y DISPOSITIVOS ESPECIALES     1    TP0025
# 987                             SETECSON INTERNACIONAL     1    TP0003
# 1000                                PÚBLICO EN GENERAL     1  TUS00126
#
#                                          DESCR  PRECIO_UNITARIO  \
# 8     TUB INCOLOY 1/2"Øx412mm J 9KW 240V PLACA          1615.00
# 24                      REPARACION DE TERMOPAR          1500.00
# ...

# %%
#Filtro por columnas
filtro3=df.iloc[ : , 9:13]       #Columnas consecutivas
#filtro3=df.iloc[ : , [1,4,6]]  #Columnas no consecutivas
filtro3
# Out:
#       COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  COSTO_TOTAL_CALCULADO  \
# 0                        52.80            434.48                  52.80
# 1                       327.18           1264.05                 327.18
# 2                       177.68           3861.29                1243.73
# 3                        38.96            140.00                  38.96
# 4                       101.71            344.83                 203.42
# ...                        ...               ...                    ...
# 1421                    102.31           4272.00                 613.88
# 1422                    104.69           4311.60                 628.12
# 1423                    596.55           6547.05                1789.64
# 1424                   1884.35           5909.84                1884.35
# 1425                     80.66          14060.00                 806.55
#
#       MARGEN_UNITARIO_CALCULADO
# 0                        381.68
# 1                        936.87
# ...

# %%
#Filtro de filas vs columnas
#Paso 1: Leemos el contenido del archivo   
df1= pd.read_excel('Detalle precios y productos fabricados 2022.xlsx', index_col=3)
df1
# Out:
#                              CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# NOMBRE_CLIENTE
# PÚBLICO EN GENERAL            F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# JUAN ANTONIO RESENDIZ UGALDE  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ANA BARBARA CRUZ PALACIOS     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# OMAR RODRIGUEZ GOMEZ          F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# PÚBLICO EN GENERAL            F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...                              ...        ...                        ...
# LUIS ENRIQUE PATIÑO PEREZ     F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# LUIS ENRIQUE PATIÑO PEREZ     F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# SEVEN DAYS ALL SPORT          F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# REVUELTA MONTECARLO           F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# CPEG SOLUTIONS                F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                               CANT       CVE_ART  \
# ...

# %%
#Paso 2: Aplicamos Filtro de filas vs columnas
filtro4=df1.loc[["REVUELTA MONTECARLO","PÚBLICO EN GENERAL"], ["COSTO_TOTAL_CALCULADO"]]
filtro4
# Out:
#                      COSTO_TOTAL_CALCULADO
# NOMBRE_CLIENTE
# REVUELTA MONTECARLO                1884.35
# REVUELTA MONTECARLO                1884.35
# PÚBLICO EN GENERAL                   52.80
# PÚBLICO EN GENERAL                  203.42
# PÚBLICO EN GENERAL                   98.82
# ...                                    ...
# PÚBLICO EN GENERAL                  733.23
# PÚBLICO EN GENERAL                  227.18
# PÚBLICO EN GENERAL                  444.27
# PÚBLICO EN GENERAL                   57.60
# PÚBLICO EN GENERAL                  635.00
#
# [96 rows x 1 columns]

# %%
#Filtro por cabecera
filtro5=df.head(15)
filtro5
# Out:
#    CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0   F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1   F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2   F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3   F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4   F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5   F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 6   F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 7   F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 8   F37048 2022-01-05   DIEGO ARMANDO LEON DURAN
# 9   F37049 2022-01-05   DIEGO ARMANDO LEON DURAN
# 10  F37050 2022-01-05   DIEGO ARMANDO LEON DURAN
# 11  F37051 2022-01-05   DIEGO ARMANDO LEON DURAN
# 12  F37052 2022-01-05   DIEGO ARMANDO LEON DURAN
# 13  F37053 2022-01-05   DIEGO ARMANDO LEON DURAN
# 14  F37054 2022-01-05   DIEGO ARMANDO LEON DURAN
#
#                          NOMBRE_CLIENTE  CANT   CVE_ART  \
# 0                    PÚBLICO EN GENERAL     1  TUE00244
# 1          JUAN ANTONIO RESENDIZ UGALDE     1  TUA00028
# ...

# %%
#Filtro de últimos registros
filtro6=df.tail(15)
filtro6
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 1411  F39820 2022-12-22         AARON NUÑO CORDOVA
# 1412  F39824 2022-12-23             ALFREDO CANELA
# 1413  F39826 2022-12-23         AARON NUÑO CORDOVA
# 1414  F39828 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1415  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1416  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1417  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1418  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1419  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1420  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                                          NOMBRE_CLIENTE  CANT       CVE_ART  \
# ...

# %% [markdown]
# FILTROS BASICOS PARA VARIABLES CUANTITATIVAS

# %%
#Filtro por comparacion
filtro7=df[df["PRECIO_UNITARIO"] > 1000]
filtro7
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 6     F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 8     F37048 2022-01-05   DIEGO ARMANDO LEON DURAN
# 9     F37049 2022-01-05   DIEGO ARMANDO LEON DURAN
# 10    F37050 2022-01-05   DIEGO ARMANDO LEON DURAN
# ...      ...        ...                        ...
# 1419  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1420  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                            NOMBRE_CLIENTE  CANT   CVE_ART  \
# 1            JUAN ANTONIO RESENDIZ UGALDE     1  TUA00028
# 6     AIRBUS HELICOPTERS MEXICO QUERETARO     1   RP00165
# 8                      FIDEICOMISO F/1596     1  TUE00207
# 9                      FIDEICOMISO F/1596     1  TUE00207
# ...

# %% [markdown]
# FILTROS BASICOS CON CONETORES LOGICOS

# %%
#Filtro Y
filtro8=df[(df["CANT"] < 5) & (df["NOMBRE_CLIENTE"] == "FIDEICOMISO F/1596")]
filtro8
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR      NOMBRE_CLIENTE  CANT  \
# 8     F37048 2022-01-05   DIEGO ARMANDO LEON DURAN  FIDEICOMISO F/1596     1
# 9     F37049 2022-01-05   DIEGO ARMANDO LEON DURAN  FIDEICOMISO F/1596     1
# 10    F37050 2022-01-05   DIEGO ARMANDO LEON DURAN  FIDEICOMISO F/1596     1
# 11    F37051 2022-01-05   DIEGO ARMANDO LEON DURAN  FIDEICOMISO F/1596     1
# 12    F37052 2022-01-05   DIEGO ARMANDO LEON DURAN  FIDEICOMISO F/1596     1
# 225   F37469 2022-02-25  LETICIA RAMIREZ HERNANDEZ  FIDEICOMISO F/1596     1
# 226   F37470 2022-02-25  LETICIA RAMIREZ HERNANDEZ  FIDEICOMISO F/1596     1
# 227   F37471 2022-02-25  LETICIA RAMIREZ HERNANDEZ  FIDEICOMISO F/1596     1
# 228   F37472 2022-02-25  LETICIA RAMIREZ HERNANDEZ  FIDEICOMISO F/1596     1
# 229   F37473 2022-02-25  LETICIA RAMIREZ HERNANDEZ  FIDEICOMISO F/1596     1
# 335   F37676 2022-03-18  LETICIA RAMIREZ HERNANDEZ  FIDEICOMISO F/1596     1
# ...

# %%
#Filtro o
filtro9=df[(df["MARGEN_UNITARIO_CALCULADO"] < 100) | (df["MARGEN_TOTAL_CALCULADO"] < 1000)]
filtro9
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1395  F39792 2022-12-20         AARON NUÑO CORDOVA
# 1406  F39813 2022-12-22  LETICIA RAMIREZ HERNANDEZ
# 1410  F39817 2022-12-22  LETICIA RAMIREZ HERNANDEZ
# 1411  F39820 2022-12-22         AARON NUÑO CORDOVA
# 1416  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ
#
#                                          NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0                                    PÚBLICO EN GENERAL     1      TUE00244
# 1                          JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 3                                  OMAR RODRIGUEZ GOMEZ     1        TP0001
# ...

# %%
#Filtro not
filtro10=df[~(df["COSTO_UNITARIO"] <=100) & ~(df["NOMBRE_CLIENTE"] == "INGENIERIA DE PLASTICOS E IMPRESIONES")]
filtro10
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 6     F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 8     F37048 2022-01-05   DIEGO ARMANDO LEON DURAN
# ...      ...        ...                        ...
# 1419  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1420  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
#
#                            NOMBRE_CLIENTE  CANT       CVE_ART  \
# 1            JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2               ANA BARBARA CRUZ PALACIOS     7        TP0007
# 4                      PÚBLICO EN GENERAL     2       BP00242
# 6     AIRBUS HELICOPTERS MEXICO QUERETARO     1       RP00165
# ...

# %% [markdown]
# FILTROS A CSV

# %%
#Convertir archivo filtrado a CSV
filtro1.to_csv("Entregable1.csv")
filtro2.to_csv("Entregable2.csv")
filtro3.to_csv("Entregable3.csv")
filtro4.to_csv("Entregable4.csv")
filtro5.to_csv("Entregable5.csv")
filtro6.to_csv("Entregable6.csv")
filtro7.to_csv("Entregable7.csv")
filtro8.to_csv("Entregable8.csv")
filtro9.to_csv("Entregable9.csv")
filtro10.to_csv("Entregable10.csv")

# %% [markdown]
# ACTIVIDAD 1.2

# %% [markdown]
# #Carga desde un archivo .xlsx sin indice
# df= pd.read_excel('Detalle precios y productos fabricados 2022.xlsx')
# #df

# %% [markdown]
# CARGAR ARCHIVOS

# %%
#Cargar archivos
dat=pd.read_excel('Datos de Facturación.xlsx')

# %% [markdown]
# VISUALIZAR ARCHIVO

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10895 entries, 0 to 10894
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CVE_DOC        10895 non-null  object
#  1   CVE_CLPV       10895 non-null  object
#  2   STATUS         10895 non-null  object
#  3   CVE_VEND       10847 non-null  float64
#  4   FECHAELAB      10895 non-null  datetime64[ns]
#  5   FECHA_DOC      10895 non-null  datetime64[ns]
#  6   FECHA_ENT      10893 non-null  object
#  7   FECHA_VEN      10895 non-null  datetime64[ns]
#  8   FECHA_CANCELA  358 non-null    datetime64[ns]
#  9   CAN_TOT        10895 non-null  float64
#  10  DES_TOT        10895 non-null  float64
#  11  DES_FIN        10895 non-null  int64
# dtypes: datetime64[ns](4), float64(3), int64(1), object(4)
# memory usage: 1021.5+ KB

# %%
dat.head()
# Out:
#   CVE_DOC    CVE_CLPV STATUS  CVE_VEND           FECHAELAB  FECHA_DOC  \
# 0  F29414        2465      C       1.0 2019-09-03 08:58:42 2019-09-03
# 1  F29415        3926      C       1.0 2019-09-03 09:55:14 2019-09-03
# 2  F29416        3926      C       1.0 2019-09-03 13:25:33 2019-09-03
# 3  F29417        3926      C       1.0 2019-09-03 13:33:23 2019-09-03
# 4  F29418        6813      C       2.0 2019-09-03 14:23:45 2019-09-03
#
#              FECHA_ENT  FECHA_VEN FECHA_CANCELA  CAN_TOT  DES_TOT  DES_FIN
# 0  2019-09-03 00:00:00 2019-09-18    2019-09-04  3980.00      0.0        0
# 1  2019-09-03 00:00:00 2019-10-03    2019-09-03  1550.00      0.0        0
# 2  2019-09-03 00:00:00 2019-10-03    2019-09-03  1550.00      0.0        0
# 3  2019-09-03 00:00:00 2019-10-03    2019-09-17  1550.00      0.0        0
# 4  2019-09-03 00:00:00 2019-09-03    2019-09-10  2435.44      0.0        0

# %% [markdown]
# LIMPIEZA DE LA BASE

# %%
#Conversión de tipo de dato de columna de tipo Object a Float
dat.CVE_CLPV = dat.CVE_CLPV.astype(float)

# %%
dat.CVE_CLPV = dat.CVE_CLPV.replace({'M':'0'}, regex=False)

# %% [markdown]
# FILTROS

# %%
#CVE_CLPV de 1000 a 2000
filtroA = dat[(dat["CVE_CLPV"] > 1000) & (dat["CVE_CLPV"] < 2000)]
filtroA
# Out:
#       CVE_DOC  CVE_CLPV STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# 18     F29432    1965.0      C       2.0 2019-09-05 11:05:04.000 2019-09-05
# 22     F29436    1965.0      C       2.0 2019-09-06 12:01:36.000 2019-09-06
# 65     F29479    1240.0      E       2.0 2019-09-11 18:38:45.000 2019-09-11
# 71     F29485    1965.0      C       2.0 2019-09-12 12:14:28.000 2019-09-12
# 72     F29486    1965.0      E       2.0 2019-09-12 12:25:52.000 2019-09-12
# ...       ...       ...    ...       ...                     ...        ...
# 10821  F40237    1757.0      E       2.0 2023-02-24 15:18:17.570 2023-02-24
# 10839  F40255    1583.0      E       2.0 2023-02-28 09:15:45.753 2023-02-28
# 10845  F40261    1786.0      E       2.0 2023-02-28 11:15:32.527 2023-02-28
# 10871  F40287    1453.0      E       1.0 2023-03-01 12:58:23.397 2023-03-01
# 10876  F40292    1082.0      E       6.0 2023-03-02 11:00:54.770 2023-03-02
#
# ...
